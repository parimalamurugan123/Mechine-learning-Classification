# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_Ads (1).csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
dataset.columns
# Out:
# Index(['User ID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
independent=dataset[['User ID', 'Age', 'Purchased', 'Gender_Male', ]] 
dataset = dataset.astype(int)

# %%
independent
# Out:
#       User ID  Age  Purchased  Gender_Male
# 0    15624510   19          0         True
# 1    15810944   35          0         True
# 2    15668575   26          0        False
# 3    15603246   27          0        False
# 4    15804002   19          0         True
# ..        ...  ...        ...          ...
# 395  15691863   46          1        False
# 396  15706071   51          1         True
# 397  15654296   50          1        False
# 398  15755018   36          0         True
# 399  15594041   49          1        False
#
# [400 rows x 4 columns]

# %%
dependent=dataset[['EstimatedSalary']]

# %%
dependent
# Out:
#      EstimatedSalary
# 0              19000
# 1              20000
# 2              43000
# 3              57000
# 4              76000
# ..               ...
# 395            41000
# 396            23000
# 397            20000
# 398            33000
# 399            36000
#
# [400 rows x 1 columns]

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
independent=dataset[["Age","EstimatedSalary","Gender_Male"]]
dependent=dataset["Purchased"]

# %%
independent.shape
# Out:
# (400, 3)

# %%
dependent
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.svm import SVC
Classifier=SVC(C=1000,kernel='rbf',gamma='scale')
Classifier.fit(X_train,Y_train)
# Out:
# SVC(C=1000)

# %%
y_pred=Classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test,y_pred)

# %%
print(cm)
# Out:
# [[77  2]
#  [22 19]]

# %%
from sklearn.metrics import classification_report
clf_report= classification_report(Y_test,y_pred)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.97      0.87        79
#            1       0.90      0.46      0.61        41
#
#     accuracy                           0.80       120
#    macro avg       0.84      0.72      0.74       120
# weighted avg       0.82      0.80      0.78       120
